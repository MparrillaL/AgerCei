# %% [markdown]
# <a href="https://colab.research.google.com/github/MparrillaL/AgerCei/blob/main/traductorPsJava.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/**
byte = (-128, 127)
short = (-32768, 32767)
int = (-2147483648, 2147483647)
long = ()
float = (-43f, 38f)
double = (-324f, 308f)
char = (0,127)
boolean = (true/false)
 */

# %%
/** ESTRUCTURA PS:

Programa: <nombrePrograma>
Autor: <Nombre Apes>
Entorno:
    //******* declaración variables
Algoritmo:
    //******* secuencia de instrucciones
Fin Programa
 */

# %%
/* ESTRUCTURA JAVA */

//Programa: nombrePrograma
//Autor: Nombre Apes
public class nombreClase{
    public static void main(String[] args){
        //Entorno:
          //******* declaración de variables
        //Algoritmo:
          //******* secuencia de instrucciones
    } //Fin Programa
}

# %%
// DECLARACIONES

// PS
<nVariable> [,<nVariable2...] es {tipo}
--
CONST <NCONSTANTE> es {tipo} <-- <valor>

// JAVA
{tipo} nvariable [=valor][,nvariable[=valor]];
--
final {tipo} nvariable = valor;

# %%
// INSTRUCCIÓN DE SALIDA y ENTRADA
// PS
Escribir <Expresión1> [,<Expresión2>...]
--
Leer <nvariable>

// JAVA
System.out.print(cadena);
system.out.println(cadena);
--
Leer.dato{tipo}()

# %% [markdown]
# // OPERADORES VAGOS Y NORMALES
# && EVALUA SOLO OP1
# & EVALUA AMBOS SIEMPRE
# --
# || EVALUA SOLO OP1
# | EVALUA AMBOS SIEMPRE
# --
# ^ TRUE SI SON DISTINTOS
# ! NEGACIÓN

# %%
from ast import Param

// ALTERNATIVA SIMPLE
//PS
Si <condicion> entonces
  //bloque
Fin Si
//JAVA
If (<expresiónBooleana>){
    //Bloque instrucciones
} //Fin Si

// ALTERNATIVA DOBLE
if (<condición>){
    //Bloque
}else{
    //Bloque
} //Fin Si

// ALTERNATIVA MÚLTIPLE
  if (expresionBoolean) {
      //Bloque
  } else if (expresionbooleana){
      //Bloque
  } else {
      //Bloque
  } //Fin Si

  // SEGUN SEA
  switch(<expresion>){
      case <lit1>:[case <lit2>:]
      //bloque
      break;
      case <lit3>:
      //bloque
      [default:
          //Bloque]
      break;
  } //Fin Según Sea

  //MIENTRAS
  while (<condicion>){
      //Bloque
  } //Fin MIENTRAS

  //REPETIR
  do{
      //Bloque
  }while(expresionBooleana);

  //PARA
  for (inicialización; expresiónBooleana; incremento){
      //Bloque
  }//Fin Para
